# %% [markdown]
# # Getting Kaggle Dataset Arthropod Taxanomy

# %%
# Lets get the data for training purposes from our kaggle dataset of Arthropod Taxanomy 
# Follow this link : https://www.kaggle.com/rohanprospects/account?isEditing=False&verifyPhone=False
# !pip install -q kaggle
from google.colab import files
files.upload()
# !mkdir ~/.kaggle
# !cp "/content/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list

# %%
# !kaggle datasets download -d mistag/arthropod-taxonomy-orders-object-detection-dataset

# %%
# !unzip /content/arthropod-taxonomy-orders-object-detection-dataset.zip

# %%
# YOLO annotations look like this in a txt file 
# category_id bbox 

# !mkdir data
# !mkdir data/train data/val
# !mkdir data/train/images data/train/annotations data/val/images data/val/annotations

# %%
# written by Cai
#You can find this code in https://github.com/ct990912/kaggle/blob/main/Arthropod_convert2coco.py
import os
import json
import random
import shutil

# %%
def getFile(root_path):
    file_list = list()
    for file in os.listdir(root_path):
        if ('.' in file) == False and file != "coco":
            file_list.append(file)
    return file_list


def getAllJson(path):
    file_list = list()
    for file in os.listdir(path):
        if file.split('.')[1] != "vott":
            file_list.append(path + '/' + file)
    return file_list


def read_json(path: str):
    with open(path, 'r') as f:
        data = json.load(f)
    return data


def getImg(path):
    img_list = list()
    for img_file in os.listdir(path):
        if img_file != "annotations":
            img_list.append(img_file)
    return img_list

# %%
def convert2coco(root_path, split_rate=0.1,saveFile=None):
    """
    Args:
        root_path(str): your data's root path, e.g., "/home/cai/data/ArTaxOr/".
        split_rate(float): Divide the dataset into training and validation sets.
        saveFile(str): if saveFile is None, converted data will store \
                in 'root_path/coco/'; if given, converted data will \
                store your own "saveFile".
    Examples:
        >>>convert2coco("/home/cai/data/ArTaxOr/", 0.1, "/home/cai/coco/")
    """
    
    if saveFile is None:
        saveFile=root_path+"coco/"
        if not os.path.exists(root_path + "coco/"):
            os.makedirs(root_path + "coco/")
        if not os.path.exists(root_path + "coco/annotations/"):
            os.makedirs(root_path + "coco/annotations/")
        if not os.path.exists(root_path + "coco/train/"):
            os.makedirs(root_path + "coco/train/")
        if not os.path.exists(root_path + "coco/val/"):
            os.makedirs(root_path + "coco/val/")
    else:
        if not os.path.exists(saveFile + "annotations/"):
            os.makedirs(saveFile + "annotations/")
        if not os.path.exists(saveFile + "train/"):
            os.makedirs(saveFile + "train/")
        if not os.path.exists(saveFile + "val/"):
            os.makedirs(saveFile + "val/")
    
    all_class_file = getFile(root_path)  # 分别获取每个分类的目录名，存在list里面
    coco_train_annotations = dict(images=list(), annotations=list(), categories=list())  # coco训练集annotations
    coco_val_annotations = dict(images=list(), annotations=list(), categories=list())  # coco验证集annotations
    coco_annotations = [coco_train_annotations, coco_val_annotations]  # 用于划分测试集和训练集
    img_idx = 10
    bbox_idx = 100000
    label_idx = 0
    # ----------------获取coco格式中的categories
    for idx, label in enumerate(all_class_file):
        category = dict(id=idx, supercategory="Arthropod", name=label)
        coco_annotations[0]["categories"].append(category)
        coco_annotations[1]["categories"].append(category)

    # ---------------获取coco格式中的images和annotations
    for each_class in all_class_file:
        print("start to convert "+each_class+'\n')
        root_img = root_path + each_class + '/'  # 某类图片的根路径
        all_annotations = getAllJson(root_path + each_class + "/annotations")  # 获取所有的json annotation
        for json_file in all_annotations:  # 访问单个json，并按splite_rate数据存入到coco_anotations中
            data = read_json(json_file)
            flag = 1 if random.random() < split_rate else 0  # 划分测试集和训练集 train:0; val: 1;
            shutil.copyfile(root_img + data["asset"]["name"],
                        saveFile + ("train/" if flag == 0 else "val/") + data["asset"]["name"])
            # ---------------获取coco格式中的image
            img = dict(file_name=data["asset"]["name"],
                       height=data["asset"]["size"]["height"],
                       width=data["asset"]["size"]["width"],
                       id=img_idx)
            coco_annotations[flag]["images"].append(img)
            #  [x, y, w, h]， 下面的代码是一张图里面的所有bbox append到annotations里面
            for region in data["regions"]:
                bbox = region["boundingBox"]
                anno = dict(image_id=img_idx, segmentation=[[]], area=240, iscrowd=0,
                            bbox=[bbox["left"], bbox["top"], bbox["width"], bbox["height"]],
                            id=bbox_idx, category_id=label_idx)
                bbox_idx += 1
                coco_annotations[flag]["annotations"].append(anno)

            img_idx += 1
        label_idx += 1

    with open(saveFile+"annotations/train.json", "w") as f:
        json.dump(coco_annotations[0], f)
    with open(saveFile + "annotations/val.json", "w") as f:
        json.dump(coco_annotations[1], f)
    print("finish...")

# %%
if __name__ == "__main__":
    convert2coco("/content/ArTaxOr/",0.1,"./")
# Out:
# start to convert Hymenoptera
#
# start to convert Lepidoptera
#
# start to convert Coleoptera
#
# start to convert Araneae
#
# start to convert Diptera
#
# start to convert Hemiptera
#
# start to convert Odonata
#
# finish...

# %%
# !rm -rf "/content/ArTaxOr"

# %%
# For train data 
json_file = "/content/annotations/train.json"
with open(json_file) as datafile:
  data = json.load(datafile)

print(data['images'][0])
print(data['annotations'][1])
# Out:
# {'file_name': '9d29e0d08d8d.jpg', 'height': 2048, 'width': 1536, 'id': 10}
# {'image_id': 11, 'segmentation': [[]], 'area': 240, 'iscrowd': 0, 'bbox': [439.1205357142857, 225.04789272030652, 183.34285714285713, 342.00191570881225], 'id': 100001, 'category_id': 0}

# %%
print(data['annotations'][4])
# Out:
# {'image_id': 15, 'segmentation': [[]], 'area': 240, 'iscrowd': 0, 'bbox': [315.83141762452107, 874.911877394636, 947.4942528735631, 504.15325670498083], 'id': 100005, 'category_id': 0}

# %%
# For training data 
for image in data["images"]:
    image_name = image['file_name'].split(".")[0]
    txt_file_path = os.path.join('/content/train',image_name+".txt")
    image_list = []
    for annotations in data['annotations']:
      if annotations['image_id'] == image['id']:
            #annotations['category_id'] = category_dict[annotations['category_id']]
            bbox = annotations['bbox']
            category = annotations['category_id']
            image_list.append((category,bbox))
    input = []
    for output in image_list:
      string_line = "{} {} {} {} {}".format(output[0], output[1][0], output[1][1],output[1][2],output[1][3])
      input.append(string_line)
    with open(txt_file_path, 'w') as fp:
      for line in input:
          fp.write(line)
          fp.write('\n')

# %%
# For val data 
json_file = "/content/annotations/val.json"
with open(json_file) as datafile:
  data = json.load(datafile)

for image in data["images"]:
    image_name = image['file_name'].split(".")[0]
    txt_file_path = os.path.join('/content/val',image_name+".txt")
    image_list = []
    for annotations in data['annotations']:
      if annotations['image_id'] == image['id']:
            #annotations['category_id'] = category_dict[annotations['category_id']]
            bbox = annotations['bbox']
            category = annotations['category_id']
            image_list.append((category,bbox))
    input = []
    for output in image_list:
      string_line = "{} {} {} {} {}".format(output[0], output[1][0], output[1][1],output[1][2],output[1][3])
      input.append(string_line)
    with open(txt_file_path, 'w') as fp:
      for line in input:
          fp.write(line)
          fp.write('\n')

# %%
# !mkdir images
# !mkdir images/train
# !mkdir images/test
# !mkdir images/train/images
# !mkdir images/train/labels
# !mkdir images/test/images
# !mkdir images/test/labels

# %%
import os
import shutil

files = os.listdir('/content/train')
for file_name in files:
  if ".txt" in file_name:
    shutil.move(os.path.join('/content/train',file_name),os.path.join('/content/images/train/labels',file_name))
  elif ".jpg" in file_name:
    shutil.move(os.path.join('/content/train',file_name),os.path.join('/content/images/train/images',file_name))

# %%
# for test data 
import os
import shutil

files = os.listdir('/content/val')
for file_name in files:
  if ".txt" in file_name:
    shutil.move(os.path.join('/content/val',file_name),os.path.join('/content/images/test/labels',file_name))
  elif ".jpg" in file_name:
    shutil.move(os.path.join('/content/val',file_name),os.path.join('/content/images/test/images',file_name))

# %%
# Lets create a YAML file data.yaml 
import yaml
'''
train: /content/images/train/images
val: /content/images/test/images

nc: 7
names: ['Coleoptera','Diptera','Hymenoptera','Hemiptera','Lepidoptera','Araneae','Odonata']
'''
# Create this yaml file and save it under images folder only
# Out:
# "\ntrain: /content/images/train/images\nval: /content/images/test/images\n\nnc: 7\nnames: ['Coleoptera','Diptera','Hymenoptera','Hemiptera','Lepidoptera','Araneae','Odonata']\n"

# %% [markdown]
# # Lets start with teh google drive setup now

# %%
# setting up YOLO is very simple actually. Its super easy 
# YOLO is also one of the most used algorithm for object detection purpose 

# Clone the github repository 
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# %%
# Install requirements.txt
# !pip install -r requirements.txt

# %%
# !pip install utils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1

# %%
import torch

from IPython.display import Image, clear_output  # to display images
#from utils.google_utils import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.12.1+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# this is the YAML file
# %cat /content/images/data.yaml
# Out:
# train: /content/images/train/images
# val: /content/images/test/images
#
# nc: 7
# names: ['Coleoptera','Diptera','Hymenoptera','Hemiptera','Lepidoptera','Araneae','Odonata']

# %% [markdown]
# # Define Model configuration and Architecture

# %%
# define number of classes based on YAML
import yaml
with open("/content/images/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
#this is the model configuration we will use for our tutorial 
# %cat /content/yolov5/models/yolov5m.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 0.67  # model depth multiple
# width_multiple: 0.75  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/yolov5m.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.67  # model depth multiple
# width_multiple: 0.75  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, C3, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# !cat /content/images/data.yaml
# Out:
# train: /content/images/train/images
# val: /content/images/test/images
#
# nc: 7
# names: ['Coleoptera','Diptera','Hymenoptera','Hemiptera','Lepidoptera','Araneae','Odonata']

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5
# !python train.py --img 416 --batch 16 --epochs 100 --data '/content/images/data.yaml' --cfg /content/yolov5/models/yolov5m.yaml --weights '' --name yolov5m_results
# Out:
# Streaming output truncated to the last 5000 lines.
# train: WARNING ⚠️ /content/images/train/images/05b85ef83c7e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      148.2       219.3      947.43      825.98]
# train: WARNING ⚠️ /content/images/train/images/05b8ee29d404.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     581.89      220.69      848.92      1129.9]
# train: WARNING ⚠️ /content/images/train/images/05bc90fac662.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     384.91      149.14      1249.2      1416.1]
# train: WARNING ⚠️ /content/images/train/images/05c374a44027.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     983.54      656.18      173.61      300.14]
# train: WARNING ⚠️ /content/images/train/images/05c68c504022.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     599.23      304.08      684.75      692.37      744.29       921.6      403.98      392.97      1185.7      18.713      149.74      240.15      1296.5      90.444      205.89      205.84      1488.3      34.307      126.34      185.57]
# train: WARNING ⚠️ /content/images/train/images/05c8d85df4cd.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     105.47      115.81      1628.9      890.49]
# train: WARNING ⚠️ /content/images/train/images/05cfb259cb33.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1195.9      904.84      1113.3      745.16]
# train: WARNING ⚠️ /content/images/train/images/05d0f8f93914.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     104.81      79.136       625.5      668.35]
# train: WARNING ⚠️ /content/images/train/images/05d1ca5de751.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     151.09      148.59      1426.2      1341.9]
# train: WARNING ⚠️ /content/images/train/images/05d1f00d3ce7.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1272.6      316.21      471.75      206.18      949.14      533.69      408.19      176.52      731.63      544.98       125.7      86.142      620.05      556.28      145.48      108.74      507.06      601.47      142.65      112.97      1337.6      910.73      104.52      100.26      1237.3      893.79
#       127.12      96.027      1081.9      838.71      161.02      145.45       659.6      981.34       398.3       220.3      816.38      690.44      146.89       115.8      689.26      820.36      108.76      70.608      686.43      711.62      161.02      138.39      620.05       779.4      86.157      122.86
#       522.59      792.11      135.59      108.74      320.62      595.82      282.48       348.8      257.06      868.37      402.54      186.41      560.73      862.72      484.46      163.81      829.09      773.75      406.78      228.77      954.79      890.96      457.62      286.67      470.33      90.268
#        477.4      405.29]
# train: WARNING ⚠️ /content/images/train/images/05d52872c6cc.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     366.29      396.33      1261.5      723.27]
# train: WARNING ⚠️ /content/images/train/images/05d8d19d6a00.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     544.63      296.19      1070.9       853.4]
# train: WARNING ⚠️ /content/images/train/images/05e11dbf1297.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      591.8      213.56      827.67      979.11]
# train: WARNING ⚠️ /content/images/train/images/05e869e80c99.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     331.07      389.74      337.72      424.39      1234.5      600.49      308.85      307.46]
# train: WARNING ⚠️ /content/images/train/images/05e9ecd095e2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      237.1       167.3      1665.9        1072]
# train: WARNING ⚠️ /content/images/train/images/05eb6d74bf79.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      70.62      180.48      1086.8      1867.5]
# train: WARNING ⚠️ /content/images/train/images/05f32e91739c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     476.89       327.8        2272      1633.7]
# train: WARNING ⚠️ /content/images/train/images/0604f86b84fd.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     128.85      390.34      1782.5      526.81]
# train: WARNING ⚠️ /content/images/train/images/060ce093bb5e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     753.59      188.22      790.23      675.29]
# train: WARNING ⚠️ /content/images/train/images/060dbc5c2758.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     74.241      390.38      1366.8        1279]
# train: WARNING ⚠️ /content/images/train/images/0613553d6aab.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      628.7      166.68      877.96      1321.4]
# train: WARNING ⚠️ /content/images/train/images/0616bac9f206.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1280.9      659.37      1016.2      571.76]
# train: WARNING ⚠️ /content/images/train/images/061c014da5a4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     882.76      751.33      370.76       670.9]
# train: WARNING ⚠️ /content/images/train/images/061e226e9680.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     542.52      748.77      291.11      182.67]
# train: WARNING ⚠️ /content/images/train/images/0621a6b2d79c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     674.82      151.05      731.71      564.97]
# train: WARNING ⚠️ /content/images/train/images/0625bf5c3cd5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     437.55      244.44      1301.3      748.27]
# train: WARNING ⚠️ /content/images/train/images/0626b5cc59f0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     196.17      561.04      945.53      961.23]
# train: WARNING ⚠️ /content/images/train/images/062eba9a4b24.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     330.82      321.43      1126.6      809.82]
# train: WARNING ⚠️ /content/images/train/images/063575228d45.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     640.23      516.08      685.12      517.55]
# train: WARNING ⚠️ /content/images/train/images/0643a1d23481.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     486.25      366.34      1285.9      1100.5]
# train: WARNING ⚠️ /content/images/train/images/06454e4e1447.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     457.07      659.13       537.5      466.88]
# train: WARNING ⚠️ /content/images/train/images/0645e501a270.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     385.75      439.63        1031      289.94]
# train: WARNING ⚠️ /content/images/train/images/064e92011511.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     192.96      179.79      837.22      579.33]
# train: WARNING ⚠️ /content/images/train/images/06505aa9fe48.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     261.02      188.32      1218.3      1765.5]
# train: WARNING ⚠️ /content/images/train/images/0656675b1bdc.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     785.86      355.72      594.78      727.39]
# train: WARNING ⚠️ /content/images/train/images/066157f1eaa5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     104.24      229.04      1012.1      1080.6]
# train: WARNING ⚠️ /content/images/train/images/0661aecd6c24.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     219.72      124.79      777.96      473.55]
# train: WARNING ⚠️ /content/images/train/images/066233b5bc2b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     921.75      915.13      329.56      222.16]
# train: WARNING ⚠️ /content/images/train/images/0666f3f6b374.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     386.45      657.16      829.79      727.79]
# train: WARNING ⚠️ /content/images/train/images/066ac9a314da.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1112.1      360.61      1192.2      1152.3]
# train: WARNING ⚠️ /content/images/train/images/0674d2a156cc.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     421.26      288.51      934.48      648.28]
# train: WARNING ⚠️ /content/images/train/images/0683429d15cb.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     923.22      666.48      200.09      283.95]
# train: WARNING ⚠️ /content/images/train/images/068a504cf971.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1493.4      1113.9      1875.7      975.69]
# train: WARNING ⚠️ /content/images/train/images/0693bf866748.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     443.19       538.1      568.81       525.2]
# train: WARNING ⚠️ /content/images/train/images/0694ecce3a90.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     269.73       957.3      967.11      912.18]
# train: WARNING ⚠️ /content/images/train/images/069f9bc36cf8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     114.05      316.93      1665.1      914.71]
# train: WARNING ⚠️ /content/images/train/images/06a17288305a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     303.87      181.42      388.23      722.95]
# train: WARNING ⚠️ /content/images/train/images/06a2d60b142f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     724.45      738.62      640.24      522.99]
# train: WARNING ⚠️ /content/images/train/images/06a39f5cf19a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     334.92      470.53      1347.8      1293.6      508.77      1103.7      941.06]
# train: WARNING ⚠️ /content/images/train/images/06a8f2649bb1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1956.3      1118.4      225.22      366.47      2668.6      1791.2      377.12      316.74      2571.7      2189.1      547.35      403.12]
# train: WARNING ⚠️ /content/images/train/images/06ad7714a5f9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       2065      895.89      1086.1      1022.1]
# train: WARNING ⚠️ /content/images/train/images/06ade97460e6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     198.91      994.57      592.28      776.83      222.44      194.21      982.56      821.95]
# train: WARNING ⚠️ /content/images/train/images/06af7a672fc4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     438.44      507.59      1081.4       522.3]
# train: WARNING ⚠️ /content/images/train/images/06b604be0582.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1828.3      1003.3      474.01      727.46      3288.6       328.9      871.48      497.74      2932.4      1.9788      818.48      362.26]
# train: WARNING ⚠️ /content/images/train/images/06c33983e1c5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1050.1      658.11      522.23      457.43]
# train: WARNING ⚠️ /content/images/train/images/06c585521451.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     492.93      468.03      240.11      447.93]
# train: WARNING ⚠️ /content/images/train/images/06c5e1ee9a20.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1110.3      449.23      937.69         512      1530.1        1024      517.89      188.32      872.95      1020.1      588.51]
# train: WARNING ⚠️ /content/images/train/images/06c6883aecb0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     435.73      387.34      924.39      572.12]
# train: WARNING ⚠️ /content/images/train/images/06c71468adb7.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      331.6      119.86       993.6        1239]
# train: WARNING ⚠️ /content/images/train/images/06cab36f23c2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      577.1      555.83      272.97      309.74]
# train: WARNING ⚠️ /content/images/train/images/06d3c88fe87b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     431.96      315.57      1019.9      1010.5]
# train: WARNING ⚠️ /content/images/train/images/06d4bd99a6bf.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     706.94      432.55      485.52      248.64]
# train: WARNING ⚠️ /content/images/train/images/06d4c2bfb7a4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     465.56      340.07      861.67      731.07]
# train: WARNING ⚠️ /content/images/train/images/06d990cc64e4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     362.74      396.45      948.49       547.9]
# train: WARNING ⚠️ /content/images/train/images/06ea7a85044b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     258.52      250.08      448.88      621.69]
# train: WARNING ⚠️ /content/images/train/images/06eaa19d3b2a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1164.4      1648.6      1256.3      2120.3]
# train: WARNING ⚠️ /content/images/train/images/06f29a5862a8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     82.687      1898.8      887.07]
# train: WARNING ⚠️ /content/images/train/images/06f3b0fdc3fb.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     349.18      1426.1      602.24      374.68]
# train: WARNING ⚠️ /content/images/train/images/06f4c2a045a8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     293.52      423.72      1257.9      841.56]
# train: WARNING ⚠️ /content/images/train/images/06fa305c7860.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     283.39       347.9      217.55      323.48]
# train: WARNING ⚠️ /content/images/train/images/06fd3fd013e2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     44.434      75.783      1281.6      1108.2]
# train: WARNING ⚠️ /content/images/train/images/070146a17637.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1287.9      928.21      907.47      238.76]
# train: WARNING ⚠️ /content/images/train/images/0702a53a0af3.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     88.107      100.05      1800.5        1948]
# train: WARNING ⚠️ /content/images/train/images/07062d0336c6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     514.66      647.94      1050.9      515.23]
# train: WARNING ⚠️ /content/images/train/images/070dd6e82571.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      212.9       314.7      1091.4      679.09]
# train: WARNING ⚠️ /content/images/train/images/07121875926e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     507.59      576.74      760.64      395.77]
# train: WARNING ⚠️ /content/images/train/images/071337140d13.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     570.62      495.23        1089      641.33]
# train: WARNING ⚠️ /content/images/train/images/07162e1a21dd.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     687.28      544.01      605.73      486.67]
# train: WARNING ⚠️ /content/images/train/images/071655faec95.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1979.3      1203.2      1511.3      1254.5]
# train: WARNING ⚠️ /content/images/train/images/07230b6488ad.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     259.13      295.35      368.68      399.01]
# train: WARNING ⚠️ /content/images/train/images/0723601bd9a1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     2250.8      1378.4      543.05      550.39]
# train: WARNING ⚠️ /content/images/train/images/07290e4be260.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     575.34      115.77      600.05      749.71]
# train: WARNING ⚠️ /content/images/train/images/0736052c39ee.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     845.45      464.05       702.9      523.81]
# train: WARNING ⚠️ /content/images/train/images/0737842af433.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      361.4      241.26      430.59      308.51]
# train: WARNING ⚠️ /content/images/train/images/0738c1136647.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     77.073       209.9        1194      1804.8]
# train: WARNING ⚠️ /content/images/train/images/074666a724ca.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     299.23      45.701       495.1      951.02]
# train: WARNING ⚠️ /content/images/train/images/074f081656a5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     578.79      440.69      563.28      667.24]
# train: WARNING ⚠️ /content/images/train/images/075a7bcbbc67.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     885.24       571.4      132.32       173.4]
# train: WARNING ⚠️ /content/images/train/images/075aa0ca677b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     485.96      307.55      1014.3      750.53]
# train: WARNING ⚠️ /content/images/train/images/075fc1689425.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     499.64      230.03      873.94      923.18]
# train: WARNING ⚠️ /content/images/train/images/076024f9b1b5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     241.74      351.14       488.7      1324.1      644.08      270.71      447.48      1326.1]
# train: WARNING ⚠️ /content/images/train/images/0763514c0b34.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     824.47       14.43      431.73      448.53      461.28      351.13      526.73      487.01]
# train: WARNING ⚠️ /content/images/train/images/076db57dbbef.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     75.383       232.8      752.09      565.52]
# train: WARNING ⚠️ /content/images/train/images/07714cf901ab.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1031.1      710.59      474.57      433.43      426.55      121.86       967.5      1012.3]
# train: WARNING ⚠️ /content/images/train/images/0772b588e611.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     466.88      1029.9      564.97      688.55]
# train: WARNING ⚠️ /content/images/train/images/0773bfc10c8f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     349.05      290.33      1035.7      1461.5]
# train: WARNING ⚠️ /content/images/train/images/07740bb82f6f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1925.7      967.37        1154      1197.3]
# train: WARNING ⚠️ /content/images/train/images/077a89c20321.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1098.3      422.25      578.21      538.48]
# train: WARNING ⚠️ /content/images/train/images/0784e7813961.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1205.4      385.63      719.83      590.14]
# train: WARNING ⚠️ /content/images/train/images/0798188e08cb.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     79.824      219.71      1256.1      1671.4]
# train: WARNING ⚠️ /content/images/train/images/07a764d83300.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     33.066      145.04      1079.2       804.2]
# train: WARNING ⚠️ /content/images/train/images/07a7b2edd801.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     912.73      900.17      60.805      55.517      465.95      380.69      643.74         690      102.44      255.11       85.92      71.379]
# train: WARNING ⚠️ /content/images/train/images/07ad759e359a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     785.75       415.1      435.96      338.34]
# train: WARNING ⚠️ /content/images/train/images/07ad8d58fa8b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     814.34      436.97      351.63      589.98]
# train: WARNING ⚠️ /content/images/train/images/07af3fa16da9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      814.4      146.19      690.19      1003.6]
# train: WARNING ⚠️ /content/images/train/images/07b5588eabfd.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1149.7      510.28      238.19      222.18      802.03      196.67      192.47      128.63]
# train: WARNING ⚠️ /content/images/train/images/07babd3ed863.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1940       770.8      1261.2      1922.8]
# train: WARNING ⚠️ /content/images/train/images/07bf1dec0233.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     542.41      704.25      525.73      849.41]
# train: WARNING ⚠️ /content/images/train/images/07c078a01566.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1266.2      1036.1      1516.1      1671.7]
# train: WARNING ⚠️ /content/images/train/images/07c459cb3860.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     207.89      223.29        1664      1219.8]
# train: WARNING ⚠️ /content/images/train/images/07cdac61aa1a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1331.3      145.16      484.39      468.84      554.71      423.72      425.56      123.59      1629.4      1212.3      154.93       184.4       711.6      209.84      266.79      170.34      37.272      1453.2      1618.4]
# train: WARNING ⚠️ /content/images/train/images/07d0c654b0e0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     455.63      197.46      1365.3      1392.1]
# train: WARNING ⚠️ /content/images/train/images/07dfa65d6a6d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     664.79      262.58      705.84      949.88]
# train: WARNING ⚠️ /content/images/train/images/07e5a2a21553.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     880.55      698.85      195.68      167.72]
# train: WARNING ⚠️ /content/images/train/images/07e6eda9aa3c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        640      1061.8      647.36      529.66]
# train: WARNING ⚠️ /content/images/train/images/07f6c22f8248.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     504.23      657.96      988.69      413.76]
# train: WARNING ⚠️ /content/images/train/images/07fc17349668.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     156.78      286.56      1614.4      917.91]
# train: WARNING ⚠️ /content/images/train/images/07fd8cb575a7.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     199.88      209.95      777.85      453.12]
# train: WARNING ⚠️ /content/images/train/images/0801b6797646.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     235.71      257.55      1102.3      954.08      1054.3      208.15       986.6      783.31]
# train: WARNING ⚠️ /content/images/train/images/08052c9f466f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     553.76       349.7      1119.5      906.59]
# train: WARNING ⚠️ /content/images/train/images/0807d12ad5f8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     943.82      692.97      326.62      188.32]
# train: WARNING ⚠️ /content/images/train/images/080fd50d2994.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     94.009      156.78       543.1      783.91]
# train: WARNING ⚠️ /content/images/train/images/0810d412e8c0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     167.14      172.16      334.28      292.78]
# train: WARNING ⚠️ /content/images/train/images/08141d6bfd04.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     708.62      519.44      1057.4      437.81]
# train: WARNING ⚠️ /content/images/train/images/0826ba82942f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     250.91      135.32      301.26      323.33]
# train: WARNING ⚠️ /content/images/train/images/082b16072b47.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       2270      437.87      556.45      323.97]
# train: WARNING ⚠️ /content/images/train/images/0831a86a07cb.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        640      120.82      1289.6      985.72]
# train: WARNING ⚠️ /content/images/train/images/08327c6e60c5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     524.01      410.48      936.43      573.52]
# train: WARNING ⚠️ /content/images/train/images/0839214c1b16.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     371.74      714.05      508.08       604.2]
# train: WARNING ⚠️ /content/images/train/images/08448328279a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     377.59      458.62      555.17      939.66]
# train: WARNING ⚠️ /content/images/train/images/084ec9034f32.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     490.42      380.57      639.51      955.34]
# train: WARNING ⚠️ /content/images/train/images/085048e2afef.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     282.49      255.96      1184.9      1044.3]
# train: WARNING ⚠️ /content/images/train/images/0851242dae3d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     477.05      160.64      1172.4      682.86]
# train: WARNING ⚠️ /content/images/train/images/08522225994e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     188.68      56.674      644.64      587.26]
# train: WARNING ⚠️ /content/images/train/images/0859ce2d9ae6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1095.6      439.89      1127.3      1020.9]
# train: WARNING ⚠️ /content/images/train/images/085b8802c44c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     545.35      859.22      674.82      545.35]
# train: WARNING ⚠️ /content/images/train/images/085bf03d08a0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     607.43      305.82      393.72      411.78]
# train: WARNING ⚠️ /content/images/train/images/085ea0200c35.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     256.98      439.42      810.18      1220.2]
# train: WARNING ⚠️ /content/images/train/images/085ef3792a34.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     76.237      144.04      647.69      392.84]
# train: WARNING ⚠️ /content/images/train/images/0861b5ac8270.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     381.09      324.83      1251.9      630.58]
# train: WARNING ⚠️ /content/images/train/images/08629b58cebf.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1001.7      384.71      987.62      1380.5]
# train: WARNING ⚠️ /content/images/train/images/087db850ce19.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     802.57      694.44       266.3      242.76]
# train: WARNING ⚠️ /content/images/train/images/087e13dc2fce.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     973.89      628.95      215.95      139.75]
# train: WARNING ⚠️ /content/images/train/images/0881c9b1c97e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     661.01      408.68      459.03      409.78]
# train: WARNING ⚠️ /content/images/train/images/08850860ade1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     332.19      178.86      1481.5      1292.8]
# train: WARNING ⚠️ /content/images/train/images/08916d69db8b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     307.51      205.97      200.02      160.43]
# train: WARNING ⚠️ /content/images/train/images/0894458b244d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     895.82      460.21      219.66      260.77]
# train: WARNING ⚠️ /content/images/train/images/08a07cf8514b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     217.75      348.69      1057.8      935.72      1172.6      535.54      784.18      669.43]
# train: WARNING ⚠️ /content/images/train/images/08a5c9f6981b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     906.14      326.04      307.98      958.37      193.62      434.72       417.9        1163      307.98      417.79      343.07      434.72      618.21      759.56      448.84      570.58      677.49      734.15]
# train: WARNING ⚠️ /content/images/train/images/08af4978064b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     836.98      652.95      454.48      374.07]
# train: WARNING ⚠️ /content/images/train/images/08b01fdbeae5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     464.72      437.89      799.17      620.07]
# train: WARNING ⚠️ /content/images/train/images/08b90d9af5e3.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     273.41      174.59      1394.4      1463.4]
# train: WARNING ⚠️ /content/images/train/images/08ba862576fc.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     313.22      199.42      529.34      700.57]
# train: WARNING ⚠️ /content/images/train/images/08bc2fc977af.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     531.07      362.05      641.24      387.17]
# train: WARNING ⚠️ /content/images/train/images/08bda0ac8e31.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     361.84      261.15      567.36      472.64]
# train: WARNING ⚠️ /content/images/train/images/08c6421318c1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     884.04      20.336      482.09      1248.9]
# train: WARNING ⚠️ /content/images/train/images/08cd78a4f6e6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1044.1      226.21      285.52      1137.9      402.76       59.31      790.34      877.24]
# train: WARNING ⚠️ /content/images/train/images/08ce18849886.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     377.11       356.4      1423.7       801.2]
# train: WARNING ⚠️ /content/images/train/images/08ced0bae7dd.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     225.83      243.76      1100.9      894.44]
# train: WARNING ⚠️ /content/images/train/images/08cfe8c1eb9a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     529.66      641.47      580.66      692.48]
# train: WARNING ⚠️ /content/images/train/images/08d183f0233d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     113.05      466.72      1497.1      841.39]
# train: WARNING ⚠️ /content/images/train/images/08d7adaa4ac5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     346.74      336.64      1559.7      913.51]
# train: WARNING ⚠️ /content/images/train/images/08d9d6f3337d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      306.3      333.69      1534.8      1377.2]
# train: WARNING ⚠️ /content/images/train/images/08db58b9e3d4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     414.96      653.87      465.78      464.49]
# train: WARNING ⚠️ /content/images/train/images/08dc5a25d095.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     846.95      471.33      1057.5      1044.3]
# train: WARNING ⚠️ /content/images/train/images/08dd2fc9832a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      355.4      253.79      512.18      460.69]
# train: WARNING ⚠️ /content/images/train/images/08e4fc3e2eaf.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      422.3      334.75      1348.1      1365.8]
# train: WARNING ⚠️ /content/images/train/images/08e8e9a79aab.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     136.83       276.6      1733.1      1054.9]
# train: WARNING ⚠️ /content/images/train/images/08ebdd22a877.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     2379.4      931.63      1171.8      1719.1]
# train: WARNING ⚠️ /content/images/train/images/08eda9458563.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     309.95      306.02      1190.7      1055.4]
# train: WARNING ⚠️ /content/images/train/images/08f256d24906.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     570.22      192.77      1044.5      848.36]
# train: WARNING ⚠️ /content/images/train/images/08f60f777383.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     453.84      377.58      893.77      652.79]
# train: WARNING ⚠️ /content/images/train/images/0908ed882c11.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1541      860.69      2098.8      1761.1]
# train: WARNING ⚠️ /content/images/train/images/090a062883bf.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      117.7      386.94      1687.5      959.26]
# train: WARNING ⚠️ /content/images/train/images/090b82c1879e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     372.97      551.72      935.72      626.76]
# train: WARNING ⚠️ /content/images/train/images/090ca3b11fe6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     921.75       737.1       394.3      251.59]
# train: WARNING ⚠️ /content/images/train/images/090deec377c9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     959.34      183.37      530.61      669.63      414.17      883.44      224.95      391.72]
# train: WARNING ⚠️ /content/images/train/images/090ebe4a783a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     765.52       664.2      865.23      266.97      73.979      733.36      948.86      397.23]
# train: WARNING ⚠️ /content/images/train/images/090ef3b95cae.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     372.15      229.52      724.13      1612.5]
# train: WARNING ⚠️ /content/images/train/images/091aaad5b6f1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     531.62      614.01       537.5      676.78]
# train: WARNING ⚠️ /content/images/train/images/091f9a5cd765.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     757.41      134.71      601.16      545.79]
# train: WARNING ⚠️ /content/images/train/images/092d16c982f0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     828.28      615.17       526.9      368.28]
# train: WARNING ⚠️ /content/images/train/images/093a1e0e5d36.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     400.64       195.8      837.22      899.92]
# train: WARNING ⚠️ /content/images/train/images/093c18fc316d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     178.29       183.2       777.5      651.49]
# train: WARNING ⚠️ /content/images/train/images/093cbd9ae9cd.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     236.38      429.61      925.92      1208.4]
# train: WARNING ⚠️ /content/images/train/images/093d66dc60d1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      660.6      145.66      965.15      1190.3]
# train: WARNING ⚠️ /content/images/train/images/0941765ec84d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1052.7      1056.1        1088      1055.6]
# train: WARNING ⚠️ /content/images/train/images/0945aacb922d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     520.45      296.67      277.29      272.11]
# train: WARNING ⚠️ /content/images/train/images/094670d505b4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     163.24      143.11      441.73         483]
# train: WARNING ⚠️ /content/images/train/images/09477cc69ef2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     305.16      503.21      959.59      218.66]
# train: WARNING ⚠️ /content/images/train/images/094ed4e66c68.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1445.6      46.157      588.84      883.56]
# train: WARNING ⚠️ /content/images/train/images/095136f61f8b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     701.49      7.9412      959.78      1232.5]
# train: WARNING ⚠️ /content/images/train/images/09538ab1e43c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     535.54      289.22      535.81      1142.7]
# train: WARNING ⚠️ /content/images/train/images/0954d4a3dcd0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     58.296      69.448      1154.7      1174.5]
# train: WARNING ⚠️ /content/images/train/images/09614c4308ed.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1928.1      275.13      113.29      147.13      1747.1      86.805      258.94      132.41        1678      160.37      54.437      1552.9      132.41      91.218      1029.1      36.782      175.08      155.95      1270.4      97.103      281.01      172.14      1036.5      257.47      151.54      136.83
#       942.34       394.3      89.747         128      795.22      478.16      166.25      204.51      839.36      354.57      113.29      116.23      751.08      250.11      154.48      167.72      845.24      192.74      173.61      160.37      690.76      306.02      141.24      186.85      621.61      459.03
#       153.01      154.48      1008.6      439.91      219.22       214.8      937.93      604.69      172.14      201.56      1267.5      628.23      238.34      282.48      765.79      803.31      160.37      133.89      789.33      601.75      157.43      217.75      706.94      845.98      144.18      257.47
#        842.3      862.16      232.46      219.22      823.17      1035.8      283.95      189.79      642.21         640      108.87      125.06       565.7      594.39      164.78       138.3      453.89      666.48      219.22      194.21      515.68      816.55      145.66      110.34      574.53      891.59
#       170.67      85.333      425.93      925.43      182.44      188.32      564.23      1181.4      126.53      129.47      517.15      1087.3      142.71      132.41      599.54      1281.5      157.43      154.48      762.85        1436      129.47      100.05      590.71      1443.3      126.53       92.69]
# train: WARNING ⚠️ /content/images/train/images/0961f3b2e3f2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1843.5      831.56      1432.7      1472.5]
# train: WARNING ⚠️ /content/images/train/images/0964754c8d95.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     238.38      222.95      1030.3      754.33]
# train: WARNING ⚠️ /content/images/train/images/0974c7c35d95.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     418.82      869.03      682.67      659.13]
# train: WARNING ⚠️ /content/images/train/images/09756afdac5e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     109.89      104.74      1271.4      945.94]
# train: WARNING ⚠️ /content/images/train/images/0978303d55ec.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     259.92      1182.9      1836.1]
# train: WARNING ⚠️ /content/images/train/images/0982b796ed19.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     879.08      441.38      366.34      579.68]
# train: WARNING ⚠️ /content/images/train/images/09842aa8e43f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     354.08      780.75      247.17      364.87]
# train: WARNING ⚠️ /content/images/train/images/0984d04701d4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     56.805      237.54      1776.4      1360.2]
# train: WARNING ⚠️ /content/images/train/images/098de4f6f9ba.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     659.76      611.95      890.11      584.14]
# train: WARNING ⚠️ /content/images/train/images/098ff472e6ae.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     906.23      847.28      172.26      77.605]
# train: WARNING ⚠️ /content/images/train/images/09924357a238.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      415.7      134.27      974.62      1200.9]
# train: WARNING ⚠️ /content/images/train/images/0992ec893327.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     901.37      288.74        1059      696.37      654.37      684.02      930.89      813.72]
# train: WARNING ⚠️ /content/images/train/images/0994232ae506.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      827.6      663.91      323.28       337.2]
# train: WARNING ⚠️ /content/images/train/images/0995407bb915.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     16.199      98.036      2014.7        1598]
# train: WARNING ⚠️ /content/images/train/images/099eb5cfacfe.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1414.5      667.29      1468.9      1861.2      3086.8      801.95      811.18      1295.7]
# train: WARNING ⚠️ /content/images/train/images/09a18cadc325.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     2036.4      874.44      900.32      1851.3]
# train: WARNING ⚠️ /content/images/train/images/09a230242f94.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     805.52      550.25      423.72      431.08]
# train: WARNING ⚠️ /content/images/train/images/09a5136d9244.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     439.42      223.63      774.87      1557.6]
# train: WARNING ⚠️ /content/images/train/images/09b8a62e68bb.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     501.41      313.81      1094.6      690.35]
# train: WARNING ⚠️ /content/images/train/images/09babfbeb104.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        187      317.79      1258.9      1492.8]
# train: WARNING ⚠️ /content/images/train/images/09c7626a80a2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     113.86      525.52      1252.5      496.32]
# train: WARNING ⚠️ /content/images/train/images/09cf5a26ebd5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     277.33      19.126      1770.7      1032.8]
# train: WARNING ⚠️ /content/images/train/images/09d062271e50.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     211.09      493.89      1451.3      496.08]
# train: WARNING ⚠️ /content/images/train/images/09d1fad13d6e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1130.5      1122.2      907.03      907.03]
# train: WARNING ⚠️ /content/images/train/images/09d8f77ac004.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     662.36      653.61      483.71      418.77      228.15      149.96      1654.8      1113.4]
# train: WARNING ⚠️ /content/images/train/images/09d8faa29a64.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     652.51      573.79       778.3      690.02]
# train: WARNING ⚠️ /content/images/train/images/09ddcf704b30.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     741.94      455.73      598.12      548.13]
# train: WARNING ⚠️ /content/images/train/images/09ec4aa650cb.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1335.6      810.08      645.07      550.16]
# train: WARNING ⚠️ /content/images/train/images/09ed1f079bd8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     582.62       117.7      773.89      1241.7]
# train: WARNING ⚠️ /content/images/train/images/09eddfa6812b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     2522.3      1574.9      278.67      375.26]
# train: WARNING ⚠️ /content/images/train/images/09f4e6863e5c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     267.04      1322.2      137.35      121.62      592.76        1128      94.184      66.697      1057.8      1090.7      86.335      68.659      961.64      1008.3      147.16      113.78        1048       880.8      141.28      103.97      1214.8      704.25      141.28      109.85      1020.5      625.78
#       155.01       143.2       938.1      731.71      155.01      123.59      841.95      759.17      103.99      107.89      743.84      661.09      103.99      72.582       647.7      413.92      125.58      78.467      641.81      745.44      98.108      80.429      529.97      816.06      96.146      64.736
#       424.01      623.82      84.373      103.97      406.35      800.37       145.2      125.55      100.25      1031.8      105.96      113.78      378.88      1061.3      123.62      103.97      237.61      1122.1      127.54      96.123      221.91      1237.8      58.865      76.506      569.21      992.61
#       78.486      56.889       720.3      929.84      86.335      72.582      794.86      914.15      188.37      100.05      498.57      1014.2      94.184      64.736      102.22      1194.7      143.24      100.05]
# ...
# train: WARNING ⚠️ /content/images/train/images/60e2c2e8671c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     736.06      376.05      551.25      679.79]
# train: WARNING ⚠️ /content/images/train/images/60e3c6db88c5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     146.55      79.112      282.28      301.64]
# train: WARNING ⚠️ /content/images/train/images/60e5c3e0747c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     290.93      451.57      1364.4       932.1]
# train: WARNING ⚠️ /content/images/train/images/60e5e4bec8f8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     440.47      345.17      747.01      1026.1]
# train: WARNING ⚠️ /content/images/train/images/60e7b4c4b549.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1800.6      463.44      1764.9      1829.9]
# train: WARNING ⚠️ /content/images/train/images/60e7f184f8e4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     622.34      611.65      1071.2       534.9      438.29      123.09      705.77      783.82]
# train: WARNING ⚠️ /content/images/train/images/60f4256f63cb.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     243.64       107.2        1250      1076.4]
# train: WARNING ⚠️ /content/images/train/images/60f4c9a342ab.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     366.84      286.41      731.71      818.02]
# train: WARNING ⚠️ /content/images/train/images/60f6167c9ba2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     252.16      580.66      653.29      971.03]
# train: WARNING ⚠️ /content/images/train/images/60f9b2020329.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     87.327      76.561      1580.3      1013.2]
# train: WARNING ⚠️ /content/images/train/images/60fb1af89917.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     262.98      89.904      849.06      1583.7]
# train: WARNING ⚠️ /content/images/train/images/6100042a1337.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      325.8      144.14      1167.4      1148.7]
# train: WARNING ⚠️ /content/images/train/images/610c0284583e.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     310.74      78.249      1486.7      1361.8]
# train: WARNING ⚠️ /content/images/train/images/610d3ef680a7.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     743.48      1341.8      164.78      266.79       655.2      1020.1      135.36      300.14      790.56      600.28      72.582      255.02      615.97      561.04      119.66      288.37]
# train: WARNING ⚠️ /content/images/train/images/611479e2cd79.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     967.61      398.49      1058.6      1135.5]
# train: WARNING ⚠️ /content/images/train/images/611ae7350aee.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1611.6      964.09      966.36      798.15]
# train: WARNING ⚠️ /content/images/train/images/611d857faf97.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     253.06      211.86        1279      1443.8]
# train: WARNING ⚠️ /content/images/train/images/612116915c50.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     741.52        1022      249.13      351.14]
# train: WARNING ⚠️ /content/images/train/images/61234be648c5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     281.28      442.22      1524.8      953.39]
# train: WARNING ⚠️ /content/images/train/images/6125cd4906be.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     244.33      292.86      640.21      461.23]
# train: WARNING ⚠️ /content/images/train/images/6126e65d6b7a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     112.92      229.47        1801      924.59]
# train: WARNING ⚠️ /content/images/train/images/612b851d063f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     709.17      561.89      824.95      614.27]
# train: WARNING ⚠️ /content/images/train/images/612dcd230007.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     206.68      352.94        1182      878.11]
# train: WARNING ⚠️ /content/images/train/images/61319e0e1113.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     39.234      498.27      1814.6      1249.6]
# train: WARNING ⚠️ /content/images/train/images/6131fce965fa.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1754.2      1224.7      1686.3      1261.6]
# train: WARNING ⚠️ /content/images/train/images/6137cdc795d3.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     256.74      456.09        1355      657.66]
# train: WARNING ⚠️ /content/images/train/images/61384ebfd450.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      175.7      129.34      453.39      387.42]
# train: WARNING ⚠️ /content/images/train/images/6138e10a1472.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     805.88      347.61      225.85      314.43      340.98      426.03      253.72      285.11      125.39       367.4      332.18       249.2      73.329      312.43      220.72      322.49      476.64       111.6       530.9      411.91]
# train: WARNING ⚠️ /content/images/train/images/6146a81b7d6c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1148.8      924.78      505.36      607.66]
# train: WARNING ⚠️ /content/images/train/images/6148ddf5623c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     746.65      420.03       777.7      478.53]
# train: WARNING ⚠️ /content/images/train/images/614ecb105aa1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1109.5      1182.4      1486.6      1362.4]
# train: WARNING ⚠️ /content/images/train/images/6150d770e780.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     339.28      89.778      1327.4      1374.2]
# train: WARNING ⚠️ /content/images/train/images/6153db365621.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     173.46      242.69      1575.7      713.46]
# train: WARNING ⚠️ /content/images/train/images/6154d1441c82.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     484.12      451.09      331.69      403.71]
# train: WARNING ⚠️ /content/images/train/images/6159babbeb57.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     128.49      264.83      1233.9      1371.2]
# train: WARNING ⚠️ /content/images/train/images/6167700b8203.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1296.9      1896.6      1125.4      1036.4      2140.1      1178.2      1561.3      1093.6]
# train: WARNING ⚠️ /content/images/train/images/61685b159c64.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     344.52      95.701      1315.9      1251.3]
# train: WARNING ⚠️ /content/images/train/images/616c409d4b58.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      714.3      575.26      451.68      388.41]
# train: WARNING ⚠️ /content/images/train/images/616d6979648b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     560.49      560.17      597.21      892.24]
# train: WARNING ⚠️ /content/images/train/images/61725dbd0ade.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     261.35      49.808      456.28      555.36]
# train: WARNING ⚠️ /content/images/train/images/6175cdf381da.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     788.13      98.687       603.1      931.94]
# train: WARNING ⚠️ /content/images/train/images/617f0461220f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      160.7      195.08      1156.8      915.51]
# train: WARNING ⚠️ /content/images/train/images/61803744f4a0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     118.76      123.95      1746.7      1379.1]
# train: WARNING ⚠️ /content/images/train/images/618065ed09c5.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     691.85      382.66      682.67      622.98]
# train: WARNING ⚠️ /content/images/train/images/618811f0092a.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     288.59      289.79      1031.7      580.68]
# train: WARNING ⚠️ /content/images/train/images/618837257079.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     210.41      96.773      1537.5      1824.4]
# train: WARNING ⚠️ /content/images/train/images/61ae1d51668c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     314.91      188.86      1385.1      1381.2]
# train: WARNING ⚠️ /content/images/train/images/61b03e157113.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     268.66      387.34      1176.2       479.2]
# train: WARNING ⚠️ /content/images/train/images/61b290363985.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     707.13       569.5      995.07      468.58      1748.8      600.55      251.24      700.05]
# train: WARNING ⚠️ /content/images/train/images/61b35085f2c8.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     712.09      473.75      567.91      545.84]
# train: WARNING ⚠️ /content/images/train/images/61b451979df4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     691.61      416.15      736.77       444.5]
# train: WARNING ⚠️ /content/images/train/images/61b5b3291d03.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     294.25      379.59      1556.6      869.52]
# train: WARNING ⚠️ /content/images/train/images/61b87b278781.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     412.68      283.94      981.05      574.66]
# train: WARNING ⚠️ /content/images/train/images/61bb129d9d0f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     622.45      200.74      470.26       483.9      767.78      617.46      531.96      357.78]
# train: WARNING ⚠️ /content/images/train/images/61bdeb17b84d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1918.5      1392.7      1096.8      843.45]
# train: WARNING ⚠️ /content/images/train/images/61c13f4f878b.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     442.89      737.76      618.18      764.11      195.62      95.261       914.1      717.49]
# train: WARNING ⚠️ /content/images/train/images/61c86bad9fa7.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     765.53      267.01      738.69       723.2]
# train: WARNING ⚠️ /content/images/train/images/61d3095ef3d2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     252.61      218.85      770.37      752.18]
# train: WARNING ⚠️ /content/images/train/images/61dadf5191d3.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     209.58      124.41      794.65      949.72]
# train: WARNING ⚠️ /content/images/train/images/61dd28b526d1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      624.4      556.99      1563.1      1263.1]
# train: WARNING ⚠️ /content/images/train/images/61e43ce03055.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     461.31      674.03      1384.7      208.49]
# train: WARNING ⚠️ /content/images/train/images/61ed4cafd521.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     983.35      1050.5      1059.9      1454.9]
# train: WARNING ⚠️ /content/images/train/images/61ed6b091f28.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     264.83      220.69      529.66      803.07]
# train: WARNING ⚠️ /content/images/train/images/61f89eb6f554.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     379.06      402.58      1034.6      1252.9]
# train: WARNING ⚠️ /content/images/train/images/6206441a2d65.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [        819      784.67      409.99      725.82]
# train: WARNING ⚠️ /content/images/train/images/6218cfeb5d23.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     420.61      331.49      1051.5      788.84]
# train: WARNING ⚠️ /content/images/train/images/621cd65f96f6.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     302.07      284.36      916.48      494.36]
# train: WARNING ⚠️ /content/images/train/images/6223417534e9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1215.7      835.09      58.555      107.96      945.01      961.27      245.93      201.62      1703.6      450.07      106.37       165.2      414.11      314.79      909.55       850.7]
# train: WARNING ⚠️ /content/images/train/images/6227f18ab5c1.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     280.88      260.11      1302.8      910.09]
# train: WARNING ⚠️ /content/images/train/images/622a48c82700.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     184.66      270.71      1220.5      1541.9]
# train: WARNING ⚠️ /content/images/train/images/623193a8e901.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     529.48      596.26      217.84      338.68]
# train: WARNING ⚠️ /content/images/train/images/62368a715b0d.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     707.47      402.44      716.88      967.18]
# train: WARNING ⚠️ /content/images/train/images/6237b3d82485.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     515.68      582.62      675.31      688.55]
# train: WARNING ⚠️ /content/images/train/images/6238cc39e8ce.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     56.497       46.94      1867.2      1069.7]
# train: WARNING ⚠️ /content/images/train/images/6239cf0fd6ef.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     995.24      578.21      982.03      948.97]
# train: WARNING ⚠️ /content/images/train/images/623df1d21c52.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     199.24      251.35      1576.9      733.97]
# train: WARNING ⚠️ /content/images/train/images/624218135cb4.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     537.23      256.99      801.87      907.34]
# train: WARNING ⚠️ /content/images/train/images/6242b16bafa2.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     718.51
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# CPU times: user 373 ms, sys: 69.6 ms, total: 443 ms
# Wall time: 12.4 s
