# %% [markdown]
# ### Basic Introduction
#
# LeNet-5, from the paper Gradient-Based Learning Applied to Document Recognition, is a very efficient convolutional neural network for handwritten character recognition.
#
#
# <a href="http://yann.lecun.com/exdb/publis/pdf/lecun-98.pdf" target="_blank">Paper: <u>Gradient-Based Learning Applied to Document Recognition</u></a>
#
# **Authors**: Yann LeCun, Léon Bottou, Yoshua Bengio, and Patrick Haffner
#
# **Published in**: Proceedings of the IEEE (1998)
#
# ### Structure of the LeNet network
#
# LeNet5 is a small network, it contains the basic modules of deep learning: convolutional layer, pooling layer, and full link layer. It is the basis of other deep learning models. Here we analyze LeNet5 in depth. At the same time, through example analysis, deepen the understanding of the convolutional layer and pooling layer.
#
# ![lenet](/content/CNN Architectures/img/lenet-5.png)
#
# LeNet-5 Total seven layer , does not comprise an input, each containing a trainable parameters; each layer has a plurality of the Map the Feature , a characteristic of each of the input FeatureMap extracted by means of a convolution filter, and then each FeatureMap There are multiple neurons.
#
# ![lenet1](/content/CNN Architectures/img/arch.jpg)
#
# Detailed explanation of each layer parameter:
#
# #### **INPUT Layer**
#
# The first is the data INPUT layer. The size of the input image is uniformly normalized to 32 * 32.
#
# > Note: This layer does not count as the network structure of LeNet-5. Traditionally, the input layer is not considered as one of the network hierarchy.
#
#
# #### **C1 layer-convolutional layer**
#
# >**Input picture**: 32 * 32
#
# >**Convolution kernel size**: 5 * 5
#
# >**Convolution kernel types**: 6
#
# >**Output featuremap size**: 28 * 28 (32-5 + 1) = 28
#
# >**Number of neurons**: 28 * 28 * 6
#
# >**Trainable parameters**: (5 * 5 + 1) * 6 (5 * 5 = 25 unit parameters and one bias parameter per filter, a total of 6 filters)
#
# >**Number of connections**: (5 * 5 + 1) * 6 * 28 * 28 = 122304
#
# **Detailed description:**
#
# 1. The first convolution operation is performed on the input image (using 6 convolution kernels of size 5 * 5) to obtain 6 C1 feature maps (6 feature maps of size 28 * 28, 32-5 + 1 = 28).
#
# 2. Let's take a look at how many parameters are needed. The size of the convolution kernel is 5 * 5, and there are 6 * (5 * 5 + 1) = 156 parameters in total, where +1 indicates that a kernel has a bias.
#
# 3. For the convolutional layer C1, each pixel in C1 is connected to 5 * 5 pixels and 1 bias in the input image, so there are 156 * 28 * 28 = 122304 connections in total. There are 122,304 connections, but we only need to learn 156 parameters, mainly through weight sharing.
#
#
# #### **S2 layer-pooling layer (downsampling layer)**
#
# >**Input**: 28 * 28
#
# >**Sampling area**: 2 * 2
#
# >**Sampling method**: 4 inputs are added, multiplied by a trainable parameter, plus a trainable offset. Results via sigmoid
#
# >**Sampling type**: 6
#
# >**Output featureMap size**: 14 * 14 (28/2)
#
# >**Number of neurons**: 14 * 14 * 6
#
# >**Trainable parameters**: 2 * 6 (the weight of the sum + the offset)
#
# >**Number of connections**: (2 * 2 + 1) * 6 * 14 * 14
#
# >The size of each feature map in S2 is 1/4 of the size of the feature map in C1.
#
# **Detailed description:**
#
# The pooling operation is followed immediately after the first convolution. Pooling is performed using 2 * 2 kernels, and S2, 6 feature maps of 14 * 14 (28/2 = 14) are obtained.
#
# The pooling layer of S2 is the sum of the pixels in the 2 * 2 area in C1 multiplied by a weight coefficient plus an offset, and then the result is mapped again.
#
# So each pooling core has two training parameters, so there are 2x6 = 12 training parameters, but there are 5x14x14x6 = 5880 connections.
#
# #### **C3 layer-convolutional layer**
#
# >**Input**: all 6 or several feature map combinations in S2
#
# >**Convolution kernel size**: 5 * 5
#
# >**Convolution kernel type**: 16
#
# >**Output featureMap size**: 10 * 10 (14-5 + 1) = 10
#
# >Each feature map in C3 is connected to all 6 or several feature maps in S2, indicating that the feature map of this layer is a different combination of the feature maps extracted from the previous layer.
#
# >One way is that the first 6 feature maps of C3 take 3 adjacent feature map subsets in S2 as input. The next 6 feature maps take 4 subsets of neighboring feature maps in S2 as input. The next three take the non-adjacent 4 feature map subsets as input. The last one takes all the feature maps in S2 as input.
#
# >**The trainable parameters are**: 6 * (3 * 5 * 5 + 1) + 6 * (4 * 5 * 5 + 1) + 3 * (4 * 5 * 5 + 1) + 1 * (6 * 5 * 5 +1) = 1516
#
# >**Number of connections**: 10 * 10 * 1516 = 151600
#
# **Detailed description:**
#
# After the first pooling, the second convolution, the output of the second convolution is C3, 16 10x10 feature maps, and the size of the convolution kernel is 5 * 5. We know that S2 has 6 14 * 14 feature maps, how to get 16 feature maps from 6 feature maps? Here are the 16 feature maps calculated by the special combination of the feature maps of S2. details as follows:
#
#
#
#
# The first 6 feature maps of C3 (corresponding to the 6th column of the first red box in the figure above) are connected to the 3 feature maps connected to the S2 layer (the first red box in the above figure), and the next 6 feature maps are connected to the S2 layer The 4 feature maps are connected (the second red box in the figure above), the next 3 feature maps are connected with the 4 feature maps that are not connected at the S2 layer, and the last is connected with all the feature maps at the S2 layer. The convolution kernel size is still 5 * 5, so there are 6 * (3 * 5 * 5 + 1) + 6 * (4 * 5 * 5 + 1) + 3 * (4 * 5 * 5 + 1) +1 * (6 * 5 * 5 + 1) = 1516 parameters. The image size is 10 * 10, so there are 151600 connections.
#
# ![lenet1](/content/CNN Architectures/img/c31.png)
#
#
# The convolution structure of C3 and the first 3 graphs in S2 is shown below:
#
# ![lenet1](/content/CNN Architectures/img/c32.png)
#
#
# #### **S4 layer-pooling layer (downsampling layer)**
#
# >**Input**: 10 * 10
#
# >**Sampling area**: 2 * 2
#
# >**Sampling method**: 4 inputs are added, multiplied by a trainable parameter, plus a trainable offset. Results via sigmoid
#
# >**Sampling type**: 16
#
# >**Output featureMap size**: 5 * 5 (10/2)
#
# >**Number of neurons**: 5 * 5 * 16 = 400
#
# >**Trainable parameters**: 2 * 16 = 32 (the weight of the sum + the offset)
#
# >**Number of connections**: 16 * (2 * 2 + 1) * 5 * 5 = 2000
#
# >The size of each feature map in S4 is 1/4 of the size of the feature map in C3
#
# **Detailed description:**
#
# S4 is the pooling layer, the window size is still 2 * 2, a total of 16 feature maps, and the 16 10x10 maps of the C3 layer are pooled in units of 2x2 to obtain 16 5x5 feature maps. This layer has a total of 32 training parameters of 2x16, 5x5x5x16 = 2000 connections.
#
# *The connection is similar to the S2 layer.*
#
# #### **C5 layer-convolution layer**
#
# >**Input**: All 16 unit feature maps of the S4 layer (all connected to s4)
#
# >**Convolution kernel size**: 5 * 5
#
# >**Convolution kernel type**: 120
#
# >**Output featureMap size**: 1 * 1 (5-5 + 1)
#
# >**Trainable parameters / connection**: 120 * (16 * 5 * 5 + 1) = 48120
#
# **Detailed description:**
#
#
# The C5 layer is a convolutional layer. Since the size of the 16 images of the S4 layer is 5x5, which is the same as the size of the convolution kernel, the size of the image formed after convolution is 1x1. This results in 120 convolution results. Each is connected to the 16 maps on the previous level. So there are (5x5x16 + 1) x120 = 48120 parameters, and there are also 48120 connections. The network structure of the C5 layer is as follows:
#
# ![lenet1](/content/CNN Architectures/img/c5.png)
#
#
# #### **F6 layer-fully connected layer**
#
# >**Input**: c5 120-dimensional vector
#
# >**Calculation method**: calculate the dot product between the input vector and the weight vector, plus an offset, and the result is output through the sigmoid function.
#
# >**Trainable parameters**: 84 * (120 + 1) = 10164
#
# **Detailed description:**
#
# Layer 6 is a fully connected layer. The F6 layer has 84 nodes, corresponding to a 7x12 bitmap, -1 means white, 1 means black, so the black and white of the bitmap of each symbol corresponds to a code. The training parameters and number of connections for this layer are (120 + 1) x84 = 10164. The ASCII encoding diagram is as follows:
#
# ![lenet1](/content/CNN Architectures/img/f61.png)
#
# The connection method of the F6 layer is as follows:
#
# ![lenet1](/content/CNN Architectures/img/f62.png)
#
#
# #### **Output layer-fully connected layer**
#
# The output layer is also a fully connected layer, with a total of 10 nodes, which respectively represent the numbers 0 to 9, and if the value of node i is 0, the result of network recognition is the number i. A radial basis function (RBF) network connection is used. Assuming x is the input of the previous layer and y is the output of the RBF, the calculation of the RBF output is:
#
# ![lenet1](/content/CNN Architectures/img/81.png)
#
# The value of the above formula w_ij is determined by the bitmap encoding of i, where i ranges from 0 to 9, and j ranges from 0 to 7 * 12-1. The closer the value of the RBF output is to 0, the closer it is to i, that is, the closer to the ASCII encoding figure of i, it means that the recognition result input by the current network is the character i. This layer has 84x10 = 840 parameters and connections.
#
# ![lenet1](/content/CNN Architectures/img/82.png)
#
#
# **Summary**
#
#
# * LeNet-5 is a very efficient convolutional neural network for handwritten character recognition.
# * Convolutional neural networks can make good use of the structural information of images.
# * The convolutional layer has fewer parameters, which is also determined by the main characteristics of the convolutional layer, that is, local connection and shared weights.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/CNN Architectures.zip"
# Out:
# Archive:  /content/drive/MyDrive/CNN Architectures.zip
#    creating: CNN Architectures/
#    creating: CNN Architectures/.ipynb_checkpoints/
#   inflating: CNN Architectures/.ipynb_checkpoints/Inception-checkpoint.ipynb
#   inflating: CNN Architectures/.ipynb_checkpoints/LeNet-checkpoint.ipynb
#   inflating: CNN Architectures/.ipynb_checkpoints/Resnet-checkpoint.ipynb
#   inflating: CNN Architectures/Alexnet.ipynb
#   inflating: CNN Architectures/Cnn_Architectures.ipynb
#    creating: CNN Architectures/img/
#   inflating: CNN Architectures/img/5x.png
#   inflating: CNN Architectures/img/5x5.png
#  extracting: CNN Architectures/img/81.png
#   inflating: CNN Architectures/img/82.png
#   inflating: CNN Architectures/img/alex3.jpg
#   inflating: CNN Architectures/img/alex4.jpg
#   inflating: CNN Architectures/img/alex512.png
#   inflating: CNN Architectures/img/alex612.png
#   inflating: CNN Architectures/img/alexnet.png
#   inflating: CNN Architectures/img/alexnet2.png
#   inflating: CNN Architectures/img/arch.jpg
#   inflating: CNN Architectures/img/atrous.gif
#   inflating: CNN Architectures/img/atrous.png
#   inflating: CNN Architectures/img/atrous2.png
#   inflating: CNN Architectures/img/b1.png
#   inflating: CNN Architectures/img/blob.png
#   inflating: CNN Architectures/img/c31.png
#   inflating: CNN Architectures/img/c32.png
#   inflating: CNN Architectures/img/c5.png
#   inflating: CNN Architectures/img/coco.png
#   inflating: CNN Architectures/img/coco1.png
#   inflating: CNN Architectures/img/compare
#   inflating: CNN Architectures/img/concur.jpg
#   inflating: CNN Architectures/img/concurrence.jpg
#   inflating: CNN Architectures/img/config2.jpg
#   inflating: CNN Architectures/img/config3.jpg
#   inflating: CNN Architectures/img/config4.png
#   inflating: CNN Architectures/img/cpmpare.jpg
#   inflating: CNN Architectures/img/dag.png
#   inflating: CNN Architectures/img/deg.jpg
#   inflating: CNN Architectures/img/dis.jpg
#   inflating: CNN Architectures/img/dis1.jpg
#   inflating: CNN Architectures/img/error.png
#   inflating: CNN Architectures/img/f1.png
#   inflating: CNN Architectures/img/f2.png
#   inflating: CNN Architectures/img/f61.png
#   inflating: CNN Architectures/img/f62.png
#   inflating: CNN Architectures/img/face.png
#  extracting: CNN Architectures/img/face1.webp
#   inflating: CNN Architectures/img/face2.png
#   inflating: CNN Architectures/img/face3.png
#   inflating: CNN Architectures/img/face4.png
#   inflating: CNN Architectures/img/fast.jpg
#   inflating: CNN Architectures/img/fast1.png
#   inflating: CNN Architectures/img/fast10.webp
#   inflating: CNN Architectures/img/fast11.webp
#  extracting: CNN Architectures/img/fast12.webp
#  extracting: CNN Architectures/img/fast13.webp
#  extracting: CNN Architectures/img/fast14.webp
#   inflating: CNN Architectures/img/fast15.webp
#  extracting: CNN Architectures/img/fast16.webp
#   inflating: CNN Architectures/img/fast17.webp
#  extracting: CNN Architectures/img/fast18.webp
#   inflating: CNN Architectures/img/fast2.png
#   inflating: CNN Architectures/img/fast3.webp
#  extracting: CNN Architectures/img/fast4.webp
#  extracting: CNN Architectures/img/fast5.webp
#   inflating: CNN Architectures/img/fast6.png
#   inflating: CNN Architectures/img/fast7.png
#  extracting: CNN Architectures/img/fast8.webp
#  extracting: CNN Architectures/img/fast9.webp
#   inflating: CNN Architectures/img/formula.png
#   inflating: CNN Architectures/img/gan.gif
#   inflating: CNN Architectures/img/gan.jpg
#  extracting: CNN Architectures/img/gif.gif
#   inflating: CNN Architectures/img/glove.png
#   inflating: CNN Architectures/img/grid1.png
#   inflating: CNN Architectures/img/grid2.png
#   inflating: CNN Architectures/img/history.jpg
#   inflating: CNN Architectures/img/idf.png
#  extracting: CNN Architectures/img/idf1.png
#  extracting: CNN Architectures/img/idf2.png
#   inflating: CNN Architectures/img/inception.png
#   inflating: CNN Architectures/img/inceptionmis.png
#   inflating: CNN Architectures/img/inceptionnetwork.png
#   inflating: CNN Architectures/img/inceptionpic.jpg
#   inflating: CNN Architectures/img/inf.png
#   inflating: CNN Architectures/img/lenet-5.png
#   inflating: CNN Architectures/img/mask.png
#   inflating: CNN Architectures/img/mask1.png
#   inflating: CNN Architectures/img/mask10.png
#   inflating: CNN Architectures/img/mask11.png
#  extracting: CNN Architectures/img/mask12.png
#   inflating: CNN Architectures/img/mask13.png
#   inflating: CNN Architectures/img/mask14.png
#   inflating: CNN Architectures/img/mask15.png
#   inflating: CNN Architectures/img/mask16.png
#   inflating: CNN Architectures/img/mask17.png
#   inflating: CNN Architectures/img/mask18.png
#   inflating: CNN Architectures/img/mask19.png
#   inflating: CNN Architectures/img/mask2.png
#   inflating: CNN Architectures/img/mask20.png
#   inflating: CNN Architectures/img/mask21.png
#   inflating: CNN Architectures/img/mask22.png
#   inflating: CNN Architectures/img/mask23.png
#   inflating: CNN Architectures/img/mask24.png
#   inflating: CNN Architectures/img/mask3.png
#   inflating: CNN Architectures/img/mask4.png
#  extracting: CNN Architectures/img/mask5.png
#   inflating: CNN Architectures/img/mask6.png
#   inflating: CNN Architectures/img/mask7.png
#   inflating: CNN Architectures/img/mask8.png
#   inflating: CNN Architectures/img/mask9.png
#   inflating: CNN Architectures/img/mnist.jpg
#   inflating: CNN Architectures/img/netconvgg.png
#   inflating: CNN Architectures/img/network.png
#   inflating: CNN Architectures/img/networkconfig.png
#  extracting: CNN Architectures/img/ng.gif
#  extracting: CNN Architectures/img/ng1.gif
#  extracting: CNN Architectures/img/ng2.gif
#   inflating: CNN Architectures/img/one.jpg
#   inflating: CNN Architectures/img/pas.png
#   inflating: CNN Architectures/img/pas2.png
#   inflating: CNN Architectures/img/permute.png
#   inflating: CNN Architectures/img/prior.png
#   inflating: CNN Architectures/img/rbm.png
#   inflating: CNN Architectures/img/rbm1.gif
#   inflating: CNN Architectures/img/res.png
#   inflating: CNN Architectures/img/res10in.png
#   inflating: CNN Architectures/img/res11in.png
#   inflating: CNN Architectures/img/res12in.png
#   inflating: CNN Architectures/img/res13in.png
#   inflating: CNN Architectures/img/res14in.png
#   inflating: CNN Architectures/img/res15in.png
#   inflating: CNN Architectures/img/res16in.png
#   inflating: CNN Architectures/img/res17in.png
#   inflating: CNN Architectures/img/res18in.png
#   inflating: CNN Architectures/img/res1in.png
#   inflating: CNN Architectures/img/res2in.png
#   inflating: CNN Architectures/img/res3in.png
#   inflating: CNN Architectures/img/res4in.png
#   inflating: CNN Architectures/img/res5in.png
#   inflating: CNN Architectures/img/res6in.png
#   inflating: CNN Architectures/img/res7in.png
#   inflating: CNN Architectures/img/res8in.png
#   inflating: CNN Architectures/img/res9in.png
#   inflating: CNN Architectures/img/residual.png
#  extracting: CNN Architectures/img/resnet11.gif
#   inflating: CNN Architectures/img/resnetnetwork.png
#   inflating: CNN Architectures/img/resnetresults.png
#   inflating: CNN Architectures/img/resnetwork.png
#   inflating: CNN Architectures/img/result.png
#   inflating: CNN Architectures/img/rsnet.png
#   inflating: CNN Architectures/img/ssd.png
#   inflating: CNN Architectures/img/ssd1.png
#   inflating: CNN Architectures/img/ssd3.png
#   inflating: CNN Architectures/img/ssdbatch.png
#   inflating: CNN Architectures/img/ssdfor.png
#   inflating: CNN Architectures/img/tablessd.png
#  extracting: CNN Architectures/img/tf.png
#   inflating: CNN Architectures/img/tf1.png
#   inflating: CNN Architectures/img/tfidf.png
#   inflating: CNN Architectures/img/ttttt.png
#   inflating: CNN Architectures/img/v4.png
#   inflating: CNN Architectures/img/variant.png
#   inflating: CNN Architectures/img/vgg.png
#   inflating: CNN Architectures/img/yolo.png
#   inflating: CNN Architectures/img/yolo1.png
#   inflating: CNN Architectures/img/yolo3.png
#   inflating: CNN Architectures/img/yolo4.png
#   inflating: CNN Architectures/img/yolo5.png
#   inflating: CNN Architectures/img/yolo6.png
#   inflating: CNN Architectures/img/yolo7.jpg
#   inflating: CNN Architectures/img/yolo9.png
#   inflating: CNN Architectures/img/yololoss.svg
#   inflating: CNN Architectures/img/yolonet.png
#   inflating: CNN Architectures/Inception.ipynb
#   inflating: CNN Architectures/LeNet.ipynb
#   inflating: CNN Architectures/Resnet.ipynb
#   inflating: CNN Architectures/VGG.ipynb

# %% [markdown]
# ### Code Implementation

# %%
import keras
import tensorflow as tf
from keras.datasets import mnist
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Flatten
from keras.models import Sequential
from keras.utils import np_utils


# Loading the dataset and perform splitting
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Peforming reshaping operation
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# Normalization
x_train = x_train / 255
x_test = x_test / 255

# One Hot Encoding
y_train = keras.utils.np_utils.to_categorical(y_train, 10)
y_test = keras.utils.np_utils.to_categorical(y_test, 10)
# Building the Model Architecture

model = Sequential()
# Select 6 feature convolution kernels with a size of 5 * 5 (without offset), and get 66 feature maps. The size of each feature map is 32−5 + 1 = 2832−5 + 1 = 28.
# That is, the number of neurons has been reduced from 10241024 to 28 ∗ 28 = 784 28 ∗ 28 = 784.
# Parameters between input layer and C1 layer: 6 ∗ (5 ∗ 5 + 1)
model.add(Conv2D(6, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1)))
# The input of this layer is the output of the first layer, which is a 28 * 28 * 6 node matrix.
# The size of the filter used in this layer is 2 * 2, and the step length and width are both 2, so the output matrix size of this layer is 14 * 14 * 6.
model.add(MaxPooling2D(pool_size=(2, 2)))
# The input matrix size of this layer is 14 * 14 * 6, the filter size used is 5 * 5, and the depth is 16. This layer does not use all 0 padding, and the step size is 1.
# The output matrix size of this layer is 10 * 10 * 16. This layer has 5 * 5 * 6 * 16 + 16 = 2416 parameters
model.add(Conv2D(16, kernel_size=(5, 5), activation='relu'))
# The input matrix size of this layer is 10 * 10 * 16. The size of the filter used in this layer is 2 * 2, and the length and width steps are both 2, so the output matrix size of this layer is 5 * 5 * 16.
model.add(MaxPooling2D(pool_size=(2, 2)))
# The input matrix size of this layer is 5 * 5 * 16. This layer is called a convolution layer in the LeNet-5 paper, but because the size of the filter is 5 * 5, #
# So it is not different from the fully connected layer. If the nodes in the 5 * 5 * 16 matrix are pulled into a vector, then this layer is the same as the fully connected layer.
# The number of output nodes in this layer is 120, with a total of 5 * 5 * 16 * 120 + 120 = 48120 parameters.
model.add(Flatten())
model.add(Dense(120, activation='relu'))
# The number of input nodes in this layer is 120 and the number of output nodes is 84. The total parameter is 120 * 84 + 84 = 10164 (w + b)
model.add(Dense(84, activation='relu'))
# The number of input nodes in this layer is 84 and the number of output nodes is 10. The total parameter is 84 * 10 + 10 = 850
model.add(Dense(10, activation='softmax'))

model.summary()
model.compile(loss=keras.metrics.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test)
print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 24, 24, 6)         156
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 6)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 16)          2416
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 120)               30840
#
#  dense_7 (Dense)             (None, 84)                10164
#
#  dense_8 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 44,426
# Trainable params: 44,426
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 469/469 [==============================] - 25s 51ms/step - loss: 0.3517 - accuracy: 0.8969 - val_loss: 0.0982 - val_accuracy: 0.9682
# Epoch 2/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0914 - accuracy: 0.9717 - val_loss: 0.0625 - val_accuracy: 0.9806
# Epoch 3/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0636 - accuracy: 0.9800 - val_loss: 0.0488 - val_accuracy: 0.9837
# Epoch 4/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0495 - accuracy: 0.9842 - val_loss: 0.0506 - val_accuracy: 0.9838
# Epoch 5/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0413 - accuracy: 0.9868 - val_loss: 0.0452 - val_accuracy: 0.9848
# Epoch 6/20
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0351 - accuracy: 0.9888 - val_loss: 0.0394 - val_accuracy: 0.9884
# Epoch 7/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0302 - accuracy: 0.9905 - val_loss: 0.0375 - val_accuracy: 0.9890
# Epoch 8/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0257 - accuracy: 0.9918 - val_loss: 0.0490 - val_accuracy: 0.9853
# Epoch 9/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.0347 - val_accuracy: 0.9888
# Epoch 10/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0201 - accuracy: 0.9937 - val_loss: 0.0384 - val_accuracy: 0.9885
# Epoch 11/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 0.0354 - val_accuracy: 0.9900
# Epoch 12/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0165 - accuracy: 0.9946 - val_loss: 0.0389 - val_accuracy: 0.9886
# Epoch 13/20
# 469/469 [==============================] - 24s 52ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.0341 - val_accuracy: 0.9906
# Epoch 14/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0445 - val_accuracy: 0.9881
# Epoch 15/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.0440 - val_accuracy: 0.9882
# Epoch 16/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.0402 - val_accuracy: 0.9906
# Epoch 17/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0452 - val_accuracy: 0.9880
# Epoch 18/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0431 - val_accuracy: 0.9890
# Epoch 19/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0415 - val_accuracy: 0.9900
# Epoch 20/20
# 469/469 [==============================] - 24s 51ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0458 - val_accuracy: 0.9877
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0458 - accuracy: 0.9877
# Test Loss: 0.045813094824552536
# Test accuracy: 0.9876999855041504
